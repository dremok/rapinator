# %%
import lyricsgenius as genius

# %%
api = genius.Genius("dg-YwkG0YhCgRm6ZEPr7hQDlFgyxDGIXncArkjy8bLglxpkW7dBT2aZFaijDrB6W")

# %%
artist_names = [
#    'eminem', 
    'kanye west', 'snoop dogg', 'bizzy bone', '2pac']
for artist_name in artist_names:
    artist = api.search_artist(artist_name, max_songs=20)
    artist.save_lyrics('txt')
# Out:
# Searching for songs by kanye west...
#
# Changing artist name to 'Kanye West'
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Ultralight Beam"
# Song 4: "Monster"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Blood on the Leaves"
# Song 8: "Black Skinhead"
# Song 9: "All Mine"
# Song 10: "Famous"
# Song 11: "Real Friends"
# Song 12: "I Love Kanye"
# Song 13: "POWER"
# Song 14: "Runaway"
# Song 15: "No More Parties in LA"
# Song 16: "Wolves"
# Song 17: "Pt. 2"
# Song 18: "FML"
# Song 19: "Waves"
# Song 20: "All Day"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Wrote Mercy to lyrics_kanyewest_mercy.txt.
# Wrote Father Stretch My Hands, Pt. 1 to lyrics_kanyewest_fatherstretchmyhandspt.1.txt.
# Wrote Ultralight Beam to lyrics_kanyewest_ultralightbeam.txt.
# Wrote Monster to lyrics_kanyewest_monster.txt.
# Wrote Bound 2 to lyrics_kanyewest_bound2.txt.
# Wrote New Slaves to lyrics_kanyewest_newslaves.txt.
# ...
